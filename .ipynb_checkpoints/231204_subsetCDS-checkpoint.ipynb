# %% [markdown]
# ## subset regions of GTF file

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
gtf = pd.read_csv("/proj/RNA_lab/Genomic_Indexes/Human/Homo_sapiens.GRCh38.108.chr.gtf", skiprows=5, header=None, sep="\t")
# Out:
# /nas/longleaf/rhel8/apps/anaconda/2021.11.ood/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
gtf
# Out:
#           0               1            2        3        4  5  6  7  \
# 0         1  ensembl_havana         gene  1471765  1497848  .  +  .
# 1         1  ensembl_havana   transcript  1471765  1497848  .  +  .
# 2         1  ensembl_havana         exon  1471765  1472089  .  +  .
# 3         1  ensembl_havana          CDS  1471885  1472089  .  +  0
# 4         1  ensembl_havana  start_codon  1471885  1471887  .  +  0
# ...      ..             ...          ...      ...      ... .. .. ..
# 3408725  MT           insdc   transcript    15888    15953  .  +  .
# 3408726  MT           insdc         exon    15888    15953  .  +  .
# 3408727  MT           insdc         gene    15956    16023  .  -  .
# 3408728  MT           insdc   transcript    15956    16023  .  -  .
# 3408729  MT           insdc         exon    15956    16023  .  -  .
#
#                                                          8
# 0        gene_id "ENSG00000160072"; gene_version "20"; ...
# ...

# %%
# CCDS is the consensus of coding sequences from NCBI 
ccds = gtf[gtf[8].str.contains("CCDS")]
ccds
# Out:
#           0               1                2         3         4  5  6  7  \
# 1         1  ensembl_havana       transcript   1471765   1497848  .  +  .
# 2         1  ensembl_havana             exon   1471765   1472089  .  +  .
# 3         1  ensembl_havana              CDS   1471885   1472089  .  +  0
# 4         1  ensembl_havana      start_codon   1471885   1471887  .  +  0
# 5         1  ensembl_havana             exon   1477274   1477350  .  +  .
# ...      ..             ...              ...       ...       ... .. .. ..
# 3408532  21          havana       stop_codon  14964716  14964718  .  -  0
# 3408533  21          havana   five_prime_utr  15064745  15065000  .  -  .
# 3408534  21          havana   five_prime_utr  15014344  15014466  .  -  .
# 3408535  21          havana   five_prime_utr  14968193  14968526  .  -  .
# 3408536  21          havana  three_prime_utr  14961235  14964715  .  -  .
#
#                                                          8
# ...

# %%
cds = ccds[ccds[2] == "CDS"]
cds
# Out:
#           0               1    2         3         4  5  6  7  \
# 3         1  ensembl_havana  CDS   1471885   1472089  .  +  0
# 6         1  ensembl_havana  CDS   1477274   1477350  .  +  2
# 8         1  ensembl_havana  CDS   1478644   1478745  .  +  0
# 10        1  ensembl_havana  CDS   1479049   1479108  .  +  0
# 12        1  ensembl_havana  CDS   1480867   1480936  .  +  0
# ...      ..             ...  ...       ...       ... .. .. ..
# 3408032  21          havana  CDS  46126503  46126541  .  +  2
# 3408034  21          havana  CDS  46128903  46128925  .  +  2
# 3408506  21          havana  CDS  14964719  14968192  .  -  0
# 3408518  21  ensembl_havana  CDS  14964719  14968192  .  -  0
# 3408530  21          havana  CDS  14964719  14968192  .  -  0
#
#                                                          8
# 3        gene_id "ENSG00000160072"; gene_version "20"; ...
# 6        gene_id "ENSG00000160072"; gene_version "20"; ...
# ...

# %%
utr3 = ccds[ccds[2] == "three_prime_utr"]
utr3
# Out:
#           0               1                2         3         4  5  6  7  \
# 37        1  ensembl_havana  three_prime_utr   1495818   1497848  .  +  .
# 198       1          havana  three_prime_utr   3433812   3435421  .  +  .
# 274       1  ensembl_havana  three_prime_utr   3433812   3438621  .  +  .
# 362       1  ensembl_havana  three_prime_utr   2403964   2405765  .  -  .
# 379       1          havana  three_prime_utr   2403974   2405765  .  -  .
# ...      ..             ...              ...       ...       ... .. .. ..
# 3407969  21  ensembl_havana  three_prime_utr  46132553  46132848  .  +  .
# 3408036  21          havana  three_prime_utr  46128929  46129808  .  +  .
# 3408512  21          havana  three_prime_utr  14961235  14964715  .  -  .
# 3408525  21  ensembl_havana  three_prime_utr  14961235  14964715  .  -  .
# 3408536  21          havana  three_prime_utr  14961235  14964715  .  -  .
#
#                                                          8
# ...

# %%
utr5 = ccds[ccds[2] == "five_prime_utr"]
utr5
# Out:
#           0               1               2         3         4  5  6  7  \
# 36        1  ensembl_havana  five_prime_utr   1471765   1471884  .  +  .
# 197       1          havana  five_prime_utr   3069197   3069259  .  +  .
# 273       1  ensembl_havana  five_prime_utr   3069203   3069259  .  +  .
# 361       1  ensembl_havana  five_prime_utr   2412503   2412564  .  -  .
# 378       1          havana  five_prime_utr   2412503   2412564  .  -  .
# ...      ..             ...             ...       ...       ... .. .. ..
# 3408523  21  ensembl_havana  five_prime_utr  15014344  15014466  .  -  .
# 3408524  21  ensembl_havana  five_prime_utr  14968193  14968526  .  -  .
# 3408533  21          havana  five_prime_utr  15064745  15065000  .  -  .
# 3408534  21          havana  five_prime_utr  15014344  15014466  .  -  .
# 3408535  21          havana  five_prime_utr  14968193  14968526  .  -  .
#
#                                                          8
# ...

# %%
# comment out when done saving 
# cds.to_csv("/nas/longleaf/home/askav/rna/autoregulation/g4/CDS.subset.gtf")
# utr5.to_csv("/nas/longleaf/home/askav/rna/autoregulation/g4/UTR3.subset.gtf")
# utr3.to_csv("/nas/longleaf/home/askav/rna/autoregulation/g4/UTR5.subset.gtf")
